# %%
import torch

# %%
! git clone https://github.com/IFMW01/loss-landscape_R252.git
# Out:
# Cloning into 'loss-landscape_R252'...
# remote: Enumerating objects: 813, done.
# remote: Counting objects: 100% (660/660), done.
# remote: Compressing objects: 100% (288/288), done.
# remote: Total 813 (delta 407), reused 565 (delta 362), pack-reused 153
# Receiving objects: 100% (813/813), 2.31 MiB | 323.00 KiB/s, done.
# Resolving deltas: 100% (470/470), done.

# %%
if torch.cuda.is_available():
    print("Found", torch.cuda.device_count(), "CUDA devices!")
    device = torch.cuda.current_device()
    print("\tAttached device is", torch.cuda.get_device_name(device))
else:
    print("We couldn't find any CUDA devices attached to this session!")
# Out:
# Found 1 CUDA devices!
# 	Attached device is Tesla T4

# %%
import shutil
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/loss-landscape_R252/src/visualization
# Out:
# /content/loss-landscape_R252/src/visualization

# %% [markdown]
# # NEW MODELS

# %% [markdown]
# # Baseline

# %% [markdown]
# removed --test

# %% [markdown]
# # Chaning landscape plots

# %%
! python plot_2D.py --vmax 20 --zlim 20 --surf_name test_loss -f /content/loss-landscape_R252/src/visualization/baseline/baseline.pth_weights_xignore=biasbn_xnorm=filter_yignore=biasbn_ynorm=filter.h5_[-1.0,1.0,31]x[-1.0,1.0,31]_rawdata.h5
# Out:
# ------------------------------------------------------------------
# plot_2d_contour
# ------------------------------------------------------------------
# loading surface file: /content/loss-landscape_R252/src/visualization/baseline/baseline.pth_weights_xignore=biasbn_xnorm=filter_yignore=biasbn_ynorm=filter.h5_[-1.0,1.0,31]x[-1.0,1.0,31]_rawdata.h5
# len(xcoordinates): 31   len(ycoordinates): 31
# max(test_loss) = 18.590953 	 min(test_loss) = 4.720827
# [[15.75259961 15.82797862 15.9855677  16.1030274  16.16616723 16.24853833
#   16.31851452 16.37122279 16.37460725 16.34112687 16.20643514 15.95096043
#   15.59926777 15.21021321 14.8606967  14.59613943 14.42754411 14.28765816
#   14.13262746 13.99837138 13.90293315 13.84749225 13.78445399 13.70707901
#   13.64977241 13.63926633 13.67902994 13.78174756 13.97400421 14.26102418
#   14.64857643]
#  [15.8401584  15.96047537 16.16852582 16.31880602 16.36633227 16.39262862
# ...

# %%
! python plot_2D.py --vmax 20 --zlim 20 --surf_name test_loss -f /content/loss-landscape_R252/src/visualization/aug/baseline_augmentations.pth_weights_xignore=biasbn_xnorm=filter_yignore=biasbn_ynorm=filter.h5_[-1.0,1.0,31]x[-1.0,1.0,31]_rawdata.h5

# %% [markdown]
# seed 43

# %%
! python plot_surface.py --cuda --model vgg19 --x=-1:1:31 --y=-1:1:31 --model_file baseline/baseline.pth --xnorm filter --xignore biasbn --ynorm filter --yignore biasbn --plot --test --raw_data
# Out:
# Rank 0 use GPU number 0 (1 GPUs available) on 3801efa7dcce
# -------------------------------------------------------------------
# setup_direction
# -------------------------------------------------------------------
# baseline/baseline.pth_weights_xignore=biasbn_xnorm=filter_yignore=biasbn_ynorm=filter.h5 is already setted up
# baseline/baseline.pth_weights_xignore=biasbn_xnorm=filter_yignore=biasbn_ynorm=filter.h5_[-1.0,1.0,31]x[-1.0,1.0,31]_rawdata.h5 is already set up
# cosine similarity between x-axis and y-axis: -0.000426
# Files already downloaded and verified
# Files already downloaded and verified
# Computing 961 values for rank 0
# Computing loss values...: 100% 961/961 [38:26<00:00,  2.40s/it]
# Rank 0 done!  Total time: 2306.44 Sync: 0.00
# ------------------------------------------------------------------
# plot_2d_contour
# ------------------------------------------------------------------
# ...

# %%
# !python h52vtp.py --surf_file baseline/baseline.pth_weights_xignore=biasbn_xnorm=filter_yignore=biasbn_ynorm=filter.h5_[-1.0,1.0,31]x[-1.0,1.0,31]_rawdata.h5 --surf_name test_loss --zmax  10 --log
# Out:
# /content/loss-landscape_R252/src/visualization/h52vtp.py:115: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if (vertexcount % 6) is 0:
# /content/loss-landscape_R252/src/visualization/h52vtp.py:118: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if (vertexcount % 6) is 5:
# /content/loss-landscape_R252/src/visualization/h52vtp.py:122: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if (vertexcount % 6) is not 5:
# /content/loss-landscape_R252/src/visualization/h52vtp.py:132: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if (vertexcount % 6) is 0:
# /content/loss-landscape_R252/src/visualization/h52vtp.py:135: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if (vertexcount % 6) is 5:
# /content/loss-landscape_R252/src/visualization/h52vtp.py:139: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if (vertexcount % 6) is not 5:
# ...

# %%
shutil.make_archive("baseline", 'zip', "baseline")
colab_link = "baseline.zip"
gdrive_link = "/content/drive/MyDrive/R252_VGG19_CIFAR100/Loss_Landscapes"
shutil.copy(colab_link, gdrive_link)
# Out:
# '/content/drive/MyDrive/R252_VGG19_CIFAR100/Loss_Landscapes/baseline.zip'

# %% [markdown]
# # Early Stopping Baseline

# %%
shutil.make_archive("best_baseline_test", 'zip', "best_baseline_test")
colab_link = "best_baseline_test.zip"
gdrive_link = "/content/drive/MyDrive/R252_VGG19_CIFAR10/Loss_Landscapes/Test"
shutil.copy(colab_link, gdrive_link)
# Out:
# '/content/drive/MyDrive/R252_VGG19_CIFAR10/Loss_Landscapes/best_baseline.zip'

# %% [markdown]
# # ES AUG

# %%
! python plot_surface.py --cuda --model vgg19 --x=-1:1:31 --y=-1:1:31 --model_file /content/loss-landscape_R252/src/visualization/best_aug_test/best_baseline_augmentations.pth --xnorm filter --xignore biasbn --ynorm filter --yignore biasbn --plot --test --raw_data
# Out:
# Rank 0 use GPU number 0 (1 GPUs available) on 11f1c6a79355
# -------------------------------------------------------------------
# setup_direction
# -------------------------------------------------------------------
# Setting up the plotting directions...
# direction file created: /content/loss-landscape_R252/src/visualization/best_aug_test/best_baseline_augmentations.pth_weights_xignore=biasbn_xnorm=filter_yignore=biasbn_ynorm=filter.h5
# cosine similarity between x-axis and y-axis: -0.001156
# Files already downloaded and verified
# Files already downloaded and verified
# Computing 961 values for rank 0
# Computing loss values...: 100% 961/961 [37:27<00:00,  2.34s/it]
# Rank 0 done!  Total time: 2247.32 Sync: 0.00
# ------------------------------------------------------------------
# plot_2d_contour
# ------------------------------------------------------------------
# ...

# %%
# !python h52vtp.py --surf_file /content/loss-landscape_R252/src/visualization/best_aug_test/best_baseline_augmentations.pth_weights_xignore=biasbn_xnorm=filter_yignore=biasbn_ynorm=filter.h5_[-1.0,1.0,31]x[-1.0,1.0,31]_rawdata.h5 --surf_name test_loss --zmax  10 --log
# Out:
# /content/loss-landscape_R252/src/visualization/h52vtp.py:115: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if (vertexcount % 6) is 0:
# /content/loss-landscape_R252/src/visualization/h52vtp.py:118: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if (vertexcount % 6) is 5:
# /content/loss-landscape_R252/src/visualization/h52vtp.py:122: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if (vertexcount % 6) is not 5:
# /content/loss-landscape_R252/src/visualization/h52vtp.py:132: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if (vertexcount % 6) is 0:
# /content/loss-landscape_R252/src/visualization/h52vtp.py:135: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if (vertexcount % 6) is 5:
# /content/loss-landscape_R252/src/visualization/h52vtp.py:139: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if (vertexcount % 6) is not 5:
# ...

# %%
shutil.make_archive("best_aug_test", 'zip', "best_aug_test")
colab_link = "best_aug_test.zip"
gdrive_link = "/content/drive/MyDrive/R252_VGG19_CIFAR100/Loss_Landscapes/Test"
shutil.copy(colab_link, gdrive_link)
# Out:
# '/content/drive/MyDrive/R252_VGG19_CIFAR100/Loss_Landscapes/Test/best_aug_test.zip'

# %% [markdown]
# # ES Dropout

# %%
! python plot_surface.py --cuda --model vgg19 --x=-1:1:31 --y=-1:1:31 --model_file best_dropout/best_baseline_dropout_0_5.pth --xnorm filter --xignore biasbn --ynorm filter --yignore biasbn --plot --test --raw_data
# Out:
# Rank 0 use GPU number 0 (1 GPUs available) on 615c322257d2
# -------------------------------------------------------------------
# setup_direction
# -------------------------------------------------------------------
# Setting up the plotting directions...
# direction file created: best_dropout/best_baseline_dropout_0_5.pth_weights_xignore=biasbn_xnorm=filter_yignore=biasbn_ynorm=filter.h5
# cosine similarity between x-axis and y-axis: -0.001232
# ...
# 100% 169001437/169001437 [00:05<00:00, 32710016.93it/s]
# Extracting cifar100/data/cifar-100-python.tar.gz to cifar100/data
# Files already downloaded and verified
# Computing 961 values for rank 0
# Computing loss values...: 100% 961/961 [37:41<00:00,  2.35s/it]
# Rank 0 done!  Total time: 2261.88 Sync: 0.00
# ------------------------------------------------------------------
# plot_2d_contour
# ------------------------------------------------------------------
# ...

# %%
# !python h52vtp.py --surf_file best_dropout/best_baseline_dropout_0_5.pth_weights_xignore=biasbn_xnorm=filter_yignore=biasbn_ynorm=filter.h5_[-1.0,1.0,31]x[-1.0,1.0,31]_rawdata.h5 --surf_name test_loss --zmax  10 --log
# Out:
# /content/loss-landscape_R252/src/visualization/h52vtp.py:115: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if (vertexcount % 6) is 0:
# /content/loss-landscape_R252/src/visualization/h52vtp.py:118: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if (vertexcount % 6) is 5:
# /content/loss-landscape_R252/src/visualization/h52vtp.py:122: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if (vertexcount % 6) is not 5:
# /content/loss-landscape_R252/src/visualization/h52vtp.py:132: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if (vertexcount % 6) is 0:
# /content/loss-landscape_R252/src/visualization/h52vtp.py:135: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if (vertexcount % 6) is 5:
# /content/loss-landscape_R252/src/visualization/h52vtp.py:139: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if (vertexcount % 6) is not 5:
# ...

# %%
shutil.make_archive("best_dropout", 'zip', "best_dropout")
colab_link = "best_dropout.zip"
gdrive_link = "/content/drive/MyDrive/R252_VGG19_CIFAR100/Loss_Landscapes"
shutil.copy(colab_link, gdrive_link)
# Out:
# '/content/drive/MyDrive/R252_VGG19_CIFAR100/Loss_Landscapes/best_dropout.zip'

# %% [markdown]
# # Train Landscape

# %% [markdown]
# Baseline

# %%
! python plot_surface.py --cuda --model vgg19 --x=-1:1:31 --y=-1:1:31 --model_file /content/loss-landscape_R252/src/visualization/best_baseline/best_baseline.pth --xnorm filter --xignore biasbn --ynorm filter --yignore biasbn --plot --batch_size 512 --data_split 5 --split_idx 4 --raw_data
# Out:
# Rank 0 use GPU number 0 (1 GPUs available) on 11f1c6a79355
# -------------------------------------------------------------------
# setup_direction
# -------------------------------------------------------------------
# Setting up the plotting directions...
# direction file created: /content/loss-landscape_R252/src/visualization/best_baseline/best_baseline.pth_weights_xignore=biasbn_xnorm=filter_yignore=biasbn_ynorm=filter.h5
# cosine similarity between x-axis and y-axis: -0.000424
# ...
# 100% 169001437/169001437 [00:12<00:00, 13034679.75it/s]
# Extracting cifar100/data/cifar-100-python.tar.gz to cifar100/data
# Files already downloaded and verified
# Computing 961 values for rank 0
# Computing loss values...: 100% 961/961 [36:09<00:00,  2.26s/it]
# Rank 0 done!  Total time: 2169.74 Sync: 0.00
# ------------------------------------------------------------------
# plot_2d_contour
# ------------------------------------------------------------------
# ...

# %%
# !python h52vtp.py --surf_file best_baseline/best_baseline.pth_weights_xignore=biasbn_xnorm=filter_yignore=biasbn_ynorm=filter.h5_[-1.0,1.0,31]x[-1.0,1.0,31]_rawdata_datasplit=5_splitidx=4.h5 --surf_name train_loss --zmax  10 --log
# Out:
# /content/loss-landscape_R252/src/visualization/h52vtp.py:115: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if (vertexcount % 6) is 0:
# /content/loss-landscape_R252/src/visualization/h52vtp.py:118: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if (vertexcount % 6) is 5:
# /content/loss-landscape_R252/src/visualization/h52vtp.py:122: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if (vertexcount % 6) is not 5:
# /content/loss-landscape_R252/src/visualization/h52vtp.py:132: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if (vertexcount % 6) is 0:
# /content/loss-landscape_R252/src/visualization/h52vtp.py:135: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if (vertexcount % 6) is 5:
# /content/loss-landscape_R252/src/visualization/h52vtp.py:139: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if (vertexcount % 6) is not 5:
# ...

# %%
shutil.make_archive("best_baseline", 'zip', "best_baseline")
colab_link = "best_baseline.zip"
gdrive_link = "/content/drive/MyDrive/R252_VGG19_CIFAR100/Loss_Landscapes/Train"
shutil.copy(colab_link, gdrive_link)
# Out:
# '/content/drive/MyDrive/R252_VGG19_CIFAR100/Loss_Landscapes/Train/best_baseline.zip'

# %%
! python plot_surface.py --cuda --model vgg19 --x=-1:1:31 --y=-1:1:31 --model_file /content/loss-landscape_R252/src/visualization/best_aug/best_baseline_augmentations.pth  --xnorm filter --xignore biasbn --ynorm filter --yignore biasbn --plot --batch_size 512 --data_split 5 --split_idx 4 --raw_data
# Out:
# Rank 0 use GPU number 0 (1 GPUs available) on 11f1c6a79355
# -------------------------------------------------------------------
# setup_direction
# -------------------------------------------------------------------
# Setting up the plotting directions...
# direction file created: /content/loss-landscape_R252/src/visualization/best_aug/best_baseline_augmentations.pth_weights_xignore=biasbn_xnorm=filter_yignore=biasbn_ynorm=filter.h5
# cosine similarity between x-axis and y-axis: -0.001156
# Files already downloaded and verified
# Files already downloaded and verified
# Computing 961 values for rank 0
# Computing loss values...: 100% 961/961 [36:14<00:00,  2.26s/it]
# Rank 0 done!  Total time: 2174.25 Sync: 0.00
# ------------------------------------------------------------------
# plot_2d_contour
# ------------------------------------------------------------------
# ...

# %%
# !python h52vtp.py --surf_file /content/loss-landscape_R252/src/visualization/best_aug/best_baseline_augmentations.pth_weights_xignore=biasbn_xnorm=filter_yignore=biasbn_ynorm=filter.h5_[-1.0,1.0,31]x[-1.0,1.0,31]_rawdata_datasplit=5_splitidx=4.h5 --surf_name train_loss --zmax  10 --log
# Out:
# /content/loss-landscape_R252/src/visualization/h52vtp.py:115: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if (vertexcount % 6) is 0:
# /content/loss-landscape_R252/src/visualization/h52vtp.py:118: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if (vertexcount % 6) is 5:
# /content/loss-landscape_R252/src/visualization/h52vtp.py:122: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if (vertexcount % 6) is not 5:
# /content/loss-landscape_R252/src/visualization/h52vtp.py:132: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if (vertexcount % 6) is 0:
# /content/loss-landscape_R252/src/visualization/h52vtp.py:135: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if (vertexcount % 6) is 5:
# /content/loss-landscape_R252/src/visualization/h52vtp.py:139: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if (vertexcount % 6) is not 5:
# ...

# %%
shutil.make_archive("best_aug", 'zip', "best_aug")
colab_link = "best_aug.zip"
gdrive_link = "/content/drive/MyDrive/R252_VGG19_CIFAR100/Loss_Landscapes/Train"
shutil.copy(colab_link, gdrive_link)
# Out:
# '/content/drive/MyDrive/R252_VGG19_CIFAR100/Loss_Landscapes/Train/best_aug.zip'
